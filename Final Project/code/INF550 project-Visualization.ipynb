# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
cc=pd.read_csv('/Users/phuongqn/Desktop/INF550/training_listing/Training_medprice_rate.csv', nrows=19)

# %%
cc.rename(columns={'Unnamed: 0': 'Zipcode'}, inplace= True)

# %%
cc['Zipcode']
# Out:
# 0     90012
# 1     90031
# 2     90032
# 3     90022
# 4     91754
# 5     91755
# 6     90640
# 7     91107
# 8     91775
# 9     91108
# 10    91006
# 11    91024
# 12    91016
# 13    91706
# 14    91010
# 15    91702
# 16    91722
# 17    91741
# 18    91740
# Name: Zipcode, dtype: int64

# %%
med_rate=cc.transpose()

# %%
med_rate.columns=['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775', '91108', '91006', '91024','91016', '91706', '91010', '91702', '91722', '91741', '91740']
med_rate=med_rate.drop(med_rate.index[0])

# %%
med_rate.index.names=['Month']
med_rate
# Out:
#             90012      90031     90032     90022     91754     91755  \
# Month
# 6/1/12   396050.0  237050.00  253550.0  229850.0  427025.0  389050.0
# 7/1/12   387500.0  235050.00  249950.0  230050.0  452050.0  418050.0
# 8/1/12   383950.0  256821.50  250050.0  238050.0  448550.0  461550.0
# 9/1/12   390050.0  252636.00  279050.0  230050.0  448550.0  498930.0
# 10/1/12  389025.0  252636.00  279050.0  239975.0  418050.0  499050.0
# ...           ...        ...       ...       ...       ...       ...
# 12/1/18  595800.0  698994.00  678938.0  470050.0  695050.0  692050.0
# 1/1/19   599050.0  642800.00  664050.0  447500.0  699550.0  686050.0
# 2/1/19   627050.0  608798.75  649550.0  480025.0  689050.0  734500.0
# 3/1/19   669050.0  656550.00  639050.0  489550.0  683050.0  688550.0
# 4/1/19   696000.0  650050.00  653500.0  493550.0  673800.0  672250.0
#
#             90640      91107     91775       91108      91006      91024  \
# Month
# ...

# %%
med_rate=med_rate.drop(['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775'], axis=1)
med_rate.plot(figsize=(25,15), linewidth=2, fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Median Housing Price', fontsize=20)
# Out:
# Text(0, 0.5, 'Median Housing Price')

# %%
dd=pd.read_csv('/Users/phuongqn/Desktop/INF550/training_listing/Training_avgprice_rate.csv', nrows=19)
dd
# Out:
#     Unnamed: 0   5/1/12   6/1/12   7/1/12   8/1/12   9/1/12  10/1/12  11/1/12  \
# 0        90012   407122   434530   419377   408158   414499   484724   487806
# 1        90031   262477   265590   266365   279112   284694   277706   280300
# 2        90032   266780   270850   265248   273852   279053   280199   289077
# 3        90022   245039   249420   252831   258539   256035   258329   270305
# 4        91754   445213   477343   511474   517962   497895   482899   495179
# 5        91755   456850   473267   478613   503713   518797   528061   480806
# 6        90640   312512   325715   337047   338702   343797   338436   325080
# 7        91107   729187   748287   716722   814956   882581   819664   813891
# 8        91775   699508   698273   668393   683425   682800   702771   688992
# 9        91108  2028391  2052287  1987225  2010967  2058738  2383972  2344727
# 10       91006  1057812  1057638   944091   959088   811558   908110   859190
# ...

# %% [markdown]
# Use all zipcodes below 91775 because the completion date is beyond the dataset's date

# %%
avg_rate=dd.transpose()

# %%
avg_rate.columns=['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775', '91108', '91006', '91024','91016', '91706', '91010', '91702', '91722', '91741', '91740']
avg_rate=avg_rate.drop(avg_rate.index[0])

# %%
avg_rate=avg_rate.drop(['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775'], axis=1)
avg_rate.plot(figsize=(25,15), linewidth=2, fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Avg Housing Price', fontsize=20)
# Out:
# Text(0, 0.5, 'Avg Housing Price')

# %%
e=pd.read_csv('/Users/phuongqn/Desktop/INF550/Rental/Rental_Price_Training.csv')

# %%
rental=e.transpose()

# %%
rental
# Out:
#                 0      1      2      3      4      5      6      7      8  \
# Unnamed: 0  90012  90031  90032  90022  91754  91755  90640  91107  91775
# 5/1/2012     2156   2058   1868   1861   2117   2191   2074   2234   2280
# 6/1/2012     2166   2047   1861   1866   2118   2198   2078   2231   2281
# 7/1/2012     2169   2045   1866   1874   2129   2208   2072   2239   2283
# 8/1/2012     2163   2057   1882   1892   2133   2212   2070   2254   2304
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 12/1/2018    2554   2479   2294   2273   2477   2504   2388   2614   2624
# 1/1/2019     2571   2456   2291   2258   2467   2494   2366   2604   2602
# 2/1/2019     2593   2426   2264   2227   2461   2489   2352   2597   2592
# 3/1/2019     2608   2407   2238   2200   2457   2487   2343   2593   2587
# 4/1/2019     2624   2398   2221   2183   2455   2484   2337   2590   2581
#
#                 9     10     11     12     13     14     15     16     17  \
# ...

# %%
rental.columns=['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775', '91108', '91006', '91024','91016', '91706', '91010', '91702', '91722', '91741', '91740']
rental=rental.drop(rental.index[0])

# %%
rental=rental.drop(['90012', '90031', '90032', '90022', '91754', '91755', '90640', '91107', '91775'], axis=1)

# %%
rental
# Out:
#            91108  91006  91024  91016  91706  91010  91702  91722  91741  \
# 6/1/2012    6139   2271   2392   2060   1898   1924   1895   1864   2075
# 7/1/2012    6184   2278   2390   2071   1892   1930   1903   1872   2083
# 8/1/2012    6240   2292   2387   2083   1898   1935   1905   1877   2080
# 9/1/2012    6270   2295   2379   2097   1902   1944   1913   1880   2084
# 10/1/2012   6292   2291   2373   2101   1906   1944   1922   1887   2095
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 12/1/2018   6294   2680   2718   2444   2201   2316   2275   2287   2490
# 1/1/2019    6312   2670   2696   2433   2193   2317   2272   2287   2480
# 2/1/2019    6211   2664   2683   2425   2179   2318   2267   2278   2472
# 3/1/2019    6018   2666   2678   2421   2171   2319   2259   2274   2466
# 4/1/2019    5977   2664   2671   2419   2172   2322   2254   2279   2460
#
#            91740
# 6/1/2012    1953
# 7/1/2012    1959
# 8/1/2012    1968
# 9/1/2012    1969
# ...

# %%
rental.plot(figsize=(25,15), linewidth=2, fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Rental Price', fontsize=20)
# Out:
# Text(0, 0.5, 'Rental Price')
